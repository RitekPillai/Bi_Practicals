# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
x = df[['Sales']]
y=df['Profit']
# Out:
#          Sales
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680
# ...        ...
# 9989   25.2480
# 9990   91.9600
# 9991  258.5760
# 9992   29.6000
# 9993  243.1600
#
# [9994 rows x 1 columns]
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)
print("Mean square Error: ",mse)
print("R-square score: ",r2)
# Out:
# Mean square Error:  61502.734965190284
# R-square score:  -0.14925790348429113

# %%
sample=[[500]]
predicted_profit = model.predict(sample)
print("Predicted Profit for Sales 500  is ",predicted_profit)
# Out:
# Predicted Profit for Sales 500  is  [96.42052929]
# /home/ritek/my_jupyter_project/jupyter_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x_test,y_test,color='blue')
plt.plot(x_test,y_pred,color='red')
plt.xlabel('sales')
plt.ylabel('profit')
plt.title('Linear regression Fit')
plt.show()
