# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
rawIrisData = load_iris()

# %%
df = pd.DataFrame(rawIrisData.data,columns=rawIrisData.feature_names)
df['target']=iris.target

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 df = pd.DataFrame(rawIrisData.data,columns=rawIrisData.feature_names)
# ----> 2 df['target']=iris.target
#       4 print(df)
#
# NameError: name 'iris' is not defined

# %%
df.tail()

# %%
# : - takes all the rows for traning
#  :-1 - takes all the column form the start except target ( which is the answer key)

x=df.iloc[:,:-1]
y=df['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LogisticRegression(max_iter=200)
model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy Score : ",accuracy)

# %%
print(classification_report(y_test,y_pred))
sample = [[6.2 	,3.4 ,5.4,2.3]]
prediction = model.predict(sample)
print("Prediction class: ",iris.target_names[prediction])
